# %% [markdown]
# <a href="https://colab.research.google.com/github/mohinilodhi/basic-programs/blob/main/Numpy2_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *** important concept of numpy library***

# %% [markdown]
# ##practice

# %%
import numpy as np
a = np.array([2, 3, 4])     ## practice of arithemetic operators
print(a)
print(a * 6)
print(a // 4)
print(a / 4)
print(a * 2)
# Out:
# [2 3 4]
# [12 18 24]
# [0 0 1]
# [0.5  0.75 1.  ]
# [4 6 8]

# %%
import numpy as np
b = np.array([2, 4, 6])
print(b)
a.size   ##size
a.dtype  ###type
# Out:
# [2 4 6]
# dtype('int64')

# %%
a.shape #shape
# Out:
# (3,)

# %%
a.ndim
# Out:
# 1

# %%
c = np.array([5, 8, 7])
print(c)
# Out:
# [5 8 7]

# %%
c = np.linspace
print(c)
# Out:
# <function linspace at 0x7e4d939f9080>

# %%
c = np.zeros(3)
print(c)
# Out:
# [0. 0. 0.]

# %%
c = np.ones(7)
print(c)
# Out:
# [1. 1. 1. 1. 1. 1. 1.]
# np.float64(1.0)

# %%
d = np.array([4, 6, 8 ])
d.sum()
# Out:
# np.int64(18)

# %%
d.max()
# Out:
# np.int64(8)

# %%
d.min()
# Out:
# np.int64(4)

# %%
d.argmax()
# Out:
# np.int64(2)

# %%
d.argmin()
# Out:
# np.int64(0)

# %%
print(a.dtype.itemsize) # Example: to get itemsize of array 'a'
# If you need to check the total bytes of an array, use a.nbytes
print(a.nbytes) # This would give the total bytes of array 'a'
# Out:
# 8
# 24

# %%
d.argmin()
# Out:
# np.int64(0)

# %%
d.argsort()
# Out:
# array([0, 1, 2])

# %%
d.argmax(axis = 0)
# Out:
# np.int64(2)

# %%
d.argmin()
# Out:
# np.int64(0)

# %%
d.argmax(axis = 0)
# Out:
# np.int64(2)

# %%
d.argmin()
# Out:
# np.int64(0)

# %%
## 2 dimensatonal
import numpy as np

p = np.array([[1, 2, 3],[2, 3, 4]])
q = np.array([[2, 4, 5],[5, 6, 8]])
print(p * q)
print(p - q)
print(p / q)
# Out:
# [[ 2  8 15]
#  [10 18 32]]
# [[-1 -2 -2]
#  [-3 -3 -4]]
# [[0.5 0.5 0.6]
#  [0.4 0.5 0.5]]

# %%
p = np.empty(3)

# %%
p = p.ravel()

# %%
p = np.array([[1, 2, 3], [6, 7, 8]])
print(p.ravel)
# Out:
# <built-in method ravel of numpy.ndarray object at 0x7e4d5d657030>

# %%
p.reshape(6, 1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [6],
#        [7],
#        [8]])

# %%
p.nonzero()
# Out:
# (array([0, 0, 0, 1, 1, 1]), array([0, 1, 2, 0, 1, 2]))

# %%
import numpy as np
e = np.array([[3, 4, 5],[9, 8, 7],[7, 6, 5]])
print(e)
print
# Out:
# [[3 4 5]
#  [9 8 7]
#  [7 6 5]]

# %%
print(e[2])
# Out:
# [7 6 5]

# %%
print(e[1])
# Out:
# [9 8 7]

# %%
print(e[0])
# Out:
# [3 4 5]

# %%
print(e[1:3])
# Out:
# [[9 8 7]
#  [7 6 5]]

# %%
print(e[1:2])
# Out:
# [[9 8 7]]

# %%
print(e[0:1])
# Out:
# [[3 4 5]]

# %%
print(e[-3])
# Out:
# [3 4 5]

# %%
print(e[-2])
# Out:
# [9 8 7]

# %%
print([-0])
# Out:
# [0]

# %%
print(e[-3])
# Out:
# [3 4 5]

# %%
import numpy as np
x = np.array ([[1, 2, 3],[5, 6, 7]])

# %%
print(x[0, 1])
# Out:
# 2

# %%
print(x[:,0])
# Out:
# [1 5]

# %%
np.argmax(d, axis=0)
# Out:
# np.int64(2)

# %%
np.argmin(d)
# Out:
# np.int64(0)
